# %% [markdown]
# <a href="https://www.bigdatauniversity.com"><img src="https://ibm.box.com/shared/static/cw2c7r3o20w9zn8gkecaeyjhgw3xdgbj.png" width="400" align="center"></a>
#
# <h1><center>IBM Applied Data Science Capstone Project By TGH</center></h1>

# %% [markdown]
# In this Notebook will be the final work on Capstone project

# %% [markdown]
# <h1>Table of contents</h1>
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#     <ol>
#         <li><a href="#1">Week 1</a></li>
#     </ol>
# </div>
# <br>
# <hr>

# %% [markdown]
# <div id="#1">
#     <h2>Week 1</h2>
# </div>

# %% [markdown]
# Lets load required libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# the welcom line

# %%
print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!

# %% [markdown]
# <h2>The End</h2>
#
#
# <h3>Thanks for review!</h3>
#
# <h4>Author:  <a href="https://www.linkedin.com/in/tawfikghozzi/">Taoufik Ghozzi</a></h4>
#
# <hr>
#
# <p>Copyright &copy; 2018 <a href="https://www.linkedin.com/in/tawfikghozzi/">Taoufik Ghozzi</a>. This notebook and its source code are released under the terms of the <a href="https://bigdatauniversity.com/mit-license/">MIT License</a>.</p>
